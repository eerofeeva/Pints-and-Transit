# %%
from bs4 import BeautifulSoup as bs
import time
import requests
from splinter import Browser
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
### NASA Mars News
url = 'https://twincities.eater.com/'

# %%
executable_path = {'executable_path': 'c:/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
browser.visit(url)
html = browser.html
soup = bs(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <html class="harmony-eater hymnal-eater fonts-loaded" lang="en">
#  <head style="">
#   <title>
#    Eater Twin Cities
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta content="Eater Twin Cities" name="apple-mobile-web-app-title"/>
#   <script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101">
#   </script>
#   <script async="" src="https://www.google-analytics.com/gtm/js?id=GTM-M6PXKL3&amp;cid=1968153319.1612024426" type="text/javascript">
#   </script>
#   <script async="" src="https://optimize-stats.voxmedia.com/tracker?key=eb62b4217933e994&amp;hostname=twincities.eater.com&amp;source=&amp;views=1&amp;root_views=1&amp;pathroot=1&amp;ttfl=917&amp;tracker_id=eda6a2d7-46be-4dc8-959a-e14a260ff5c0&amp;_=0.18881961180786577" type="text/javascript">
#   </script>
#   <script async="" src="https://tag.mtrcs.samba.tv/v3/tag/vox/vox-eater/sambaTag.js" type="text/javascript">
#   </script>
#   <script async="" src="//static.ads-twitter.com/uwt.js">
#   </script>
#   <script async="" src="https://sb.scorecardresearch.com/beacon.js">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbds.js">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-TWPZVJD&amp;l=dataLayer" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.google-analytics.com/plugins/ua/linkid.js" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-GMSWCRTSTY&amp;l=dataLayer&amp;cx=c" type="text/javascript">
#   </script>
#   <script async="" src="https://auth.voxmedia.com/sso/unison_request?community_id=486&amp;t=1612024421920">
#   </script>
#   <script async="" src="https://optimize-stats.voxmedia.com/alternatives?key=eb62b4217933e994&amp;experiments=h:-207230013,h:-1094734654,h:-175898626,h:-208128545,h:-831388013,h:-829653278,h:-208151427,h:-208215094,h:-829716676,h:-829660072,h:-829681182,h:1659168229,h:-830724886,h:1690446791,h:-830668159,h:-831468513,h:-1800519160,h:-831651257,h:-832367299,h:-1724514410,h:-832549614,h:-833291622,h:-833436803,h:-1721657296,h:-834304493,h:-144501117,h:-834420678,h:-835109834,h:-836001646,h:-836208324,h:-837069190,h:-865732169,h:-972948118,h:-972950000,h:-1003245437&amp;source=&amp;hostname=twincities.eater.com&amp;_=0.35498126701549415&amp;callback=cback3bjn3ekbhi4f411j3rv5" type="text/javascript">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-W8JKW6">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js">
#   </script>
#   <script src="https://optimize-stats.voxmedia.com/loader.min.js?key=eb62b4217933e994" type="text/javascript">
#   </script>
#   <meta content="6029273333,242726355745404,115169205199800,139755792796580,131547960225574,213601342019363,301223156562915,309491225851948,243335249017579,348494641841991,109814609047278,442143005803582,110073695686645,385346484849141,451388614896528,240433149442075,670887879603309,150611155024023,176453365796072,110358775652218,465169560201718,105842919452319,213198508690703,192135047484517,243781239374345,111376838888644" property="fb:pages"/>
#   <link href="https://use.typekit.net/zzo8vgh.css" media="all" rel="stylesheet"/>
#   <meta data-cdata='{"version":"c21d9ae195b0d525cd96fab205882683","fonts_catalog":[],"font_stylesheets":["https://use.typekit.net/zzo8vgh.css"],"font_tracker_stylesheets":[],"typekit_ids":[],"headline_balance_div_classes":".c-entry-box--compact__title,.c-entry-box--compact__dek","headline_balance_fraction":0.5}' data-cid="site/font_loader-1612021451_3322_204801" id="chorus-fonts"/>
#   <script data-privacy-no-concern="">
#    var chorusInitQueue=[],volume_embed_host="https://volume.vox-cdn.com";var Chorus=Chorus||{};Chorus.windowLoaded=!1,Chorus.AddScript=function(t,e){var o=document.createElement("script");o.async=!0,o.type="text/javascript",o.src=t,"function"==typeof e&&(o.onload=e);var a=document.getElementsByTagName("script")[0];return a.parentNode.insertBefore(o,a),o},Chorus.ready=function(t){"loading"!=document.readyState?t():document.addEventListener?document.addEventListener("DOMContentLoaded",t):document.attachEvent("onreadystatechange",function(){"loading"!=document.readyState&&t()})},Chorus.OnLoad=function(t){if(Chorus.windowLoaded=!0)return void t();var e=window.onload;"function"!=typeof window.onload?window.onload=t:window.onload=function(){e(),t()}},Chorus.OnLoad(function(){Chorus.windowLoaded=!0});var dataLayer=dataLayer||[];Chorus.OnLoad(function(){var t;void 0!==navigator.doNotTrack?t=navigator.doNotTrack:void 0!==window.doNotTrack?t=window.doNotTrack:void 0!==navigator.msDoNotTrack&&(t=navigator.msDoNotTrack),t=void 0!==t?/1|yes|true/.test(String(t).toLowerCase())?"true":"false":"undefined";var e={DNT:t};dataLayer.push(e)});var VoxMediaFontLoader=function(t){function e(t,e){var o=window.performance;if(o&&o.mark&&o.measure){var a=t.toLocaleLowerCase().replace(/\W+/g,"_")+(e?"_"+e:"");o.mark(a),o.measure(a+"_time","navigationStart",a)}}function o(){s.classList.add(c),e("fonts_success")}function a(){s.classList.add(c),e("fonts_fail")}function n(t){var o=[t.family,t.style,t.weight,"loaded"].join(" ");e(o)}function r(t){var e=u.font_stylesheets||[];t&&(e=e.filter(function(e){return!e.match(t)})),e.forEach(i)}function i(e){var o=t.createElement("link");o.href=e,o.rel="stylesheet",o.media="all",f.parentNode.insertBefore(o,f)}function d(e){var o,a=t,n=a.documentElement,r=setTimeout(function(){n.className=n.className.replace(/\bwf-loading\b/g,"")+" wf-inactive"},e.scriptTimeout),i=a.createElement("script"),d=!1,c=a.getElementsByTagName("script")[0];n.className+=" wf-loading",i.src="https://use.typekit.net/"+e.kitId+".js",i.async=!0,i.onload=i.onreadystatechange=function(){if(o=this.readyState,!(d||o&&"complete"!=o&&"loaded"!=o)){d=!0,clearTimeout(r);try{Typekit.load(e)}catch(t){}}},c.parentNode.insertBefore(i,c)}var c="fonts-loaded",s=t.documentElement,f=t.getElementById("chorus-fonts");if(f){var u=JSON.parse(f.getAttribute("data-cdata"));t.fonts?(r("voxmedia.com"),u.fonts_catalog.forEach(function(e){if(e.woff2_url||e.woff_url){var o=[e.woff2_url,e.woff_url].filter(function(t){return t}).map(function(t){return"url("+t+")"}).join(", "),a=new FontFace(e.family,o,{weight:e.weight,style:e.style});t.fonts.add(a),a.load().then(n)}}),t.fonts.ready.then(o,a)):r(),u.typekit_ids.forEach(function(t){d({kitId:t,scriptTimeout:3e3,async:!0})}),u.font_tracker_stylesheets.forEach(i)}};VoxMediaFontLoader(document);
#   </script>
#   <script>
#    dataLayer = [{"Network":"eater","Community":"twincities.eater","root_domain":"eater.com","GA Primary ID":"UA-189494-73","GA Secondary ID":"UA-189494-82","GA CrossDomains":"eater.com,atlanta.eater.com,austin.eater.com,boston.eater.com,carolinas.eater.com,chicago.eater.com,dallas.eater.com,dc.eater.com,denver.eater.com,detroit.eater.com,houston.eater.com,la.eater.com,london.eater.com,miami.eater.com,montreal.eater.com,nashville.eater.com,nola.eater.com,ny.eater.com,philly.eater.com,phoenix.eater.com,pdx.eater.com,sandiego.eater.com,seattle.eater.com,sf.eater.com,twincities.eater.com,vegas.eater.com","Demand Post":"no","All Chorus Categories":"eater:twincities.eater","Content Type":"homepage","chartbeat_domain":"twincities.eater.com","chartbeat_zone":"172968584/eater/twincities.eater.com/front_page","Logged in Status":"Logged Out","auth0_id":"No Auth0 ID","section":"Front Page","enable_url_cleaning":true,"ScrollSubscription":"false"}];
#   </script>
#   <!-- Google Optimize -->
#   <!-- Page hiding snippet -->
#   <style>
#    .async-hide { opacity: 0 !important}
#   </style>
#   <script>
#    (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
# })(window,document.documentElement,'async-hide','dataLayer',4000,
# {'GTM-M6PXKL3':true});
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#   ga('create', 'UA-189494-73', 'auto', {'allowLinker': true,'useAmpClientId': true});
#   ga('require', 'GTM-M6PXKL3');
#   </script>
#   <!-- End Google Optimize -->
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-W8JKW6');
#   </script>
#   <!-- End Google Tag Manager -->
#   <link href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/>
#   <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="https://stats.g.doubleclick.net" rel="dns-prefetch"/>
#   <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="https://cdn.permutive.com" rel="dns-prefetch"/>
#   <link href="https://mb.moatads.com" rel="dns-prefetch"/>
#   <script>
#    var concertAdsQueue = concertAdsQueue || [];
#
#   CONCERT_ADS_CONFIG = {"production":true,"slug":"/172968584/eater/twincities.eater.com/front_page","dfpVariables":{"network":["eater"],"affiliation":["general"],"unison":[true],"page_type":["home_page"],"entry_group":["front-page"],"keywords":["eater","twin","cities","front-page"]},"isUnison":true,"is_unison":true,"prebid":{"biddingEnabled":false,"prebidEnabled":false,"rubiconDemandManagerEnabled":false,"timeout":1000,"amazonPubId":3176,"priceGranularity":"dense","defaultConfig":{"openx":{"delDomain":"sbnationbidder-d.openx.net"},"rubicon":{"accountId":7470,"position":"btf"},"rubiconLite":{"accountId":18288,"siteId":193902,"sizes":[213,270,271,272],"position":"btf"},"consumable":{"networkId":9969,"siteId":1039096},"rubi__mm":{"accountId":21670,"siteId":294140,"zoneId":1480258,"zoneName":"SBNation_MediaMath DC"},"rubi__ttd":{"accountId":21670,"siteId":294142,"zoneName":"SBNation_TTD DC","zoneId":1480284},"usersync":{"userIds":[{"name":"unifiedId","params":{"url":"https://match.adsrvr.org/track/rid?ttd_pid=gs8reto\u0026fmt=json"},"storage":{"type":"cookie","name":"pbjs-unifiedid","expires":14},"syncDelay":3000}]}},"prelude":{"trustx":{"uid":2663},"consumable":{"unitId":7423,"unitName":"cnsmbl-video-970x250"}},"reskin":{"trustx":{"uid":2664}},"desktop_leaderboard_variable":{"trustx":{"uid":2665}},"medium_rectangle_variable":{"trustx":{"uid":2666}},"btf_medium_rectangle_variable":{"trustx":{"uid":2668}},"desktop_article_medrec_dynamic":{"trustx":{"uid":2669}},"btf_leaderboard_variable":{"trustx":{"uid":2670}},"native_ad_latest":{"trustx":{"uid":2671}},"native_ad_ymal_link":{"trustx":{"uid":2672}},"mobile_leaderboard":{"trustx":{"uid":2673}},"mobile_article_body":{"trustx":{"uid":2674}},"native_ad_mobile":{"trustx":{"uid":2675}},"mobile_article_body_med_rec_dynamic":{"trustx":{"uid":2676}},"mobile_footer":{"trustx":{"uid":2677}},"tablet_leaderboard":{"trustx":{"uid":2678}},"tablet_medium_rectangle":{"trustx":{"uid":2679}},"tablet_btf_leaderboard":{"trustx":{"uid":2680}},"native_ad_content_link":{"trustx":{"uid":2681}},"hub_river_leaderboard":{"trustx":{"uid":2682}},"hub_river_med_rec":{"trustx":{"uid":2684}},"mobile_med_rec_athena":{"trustx":{"uid":2685}}},"slots":[{"name":"buy_button","type":"buy_button","selector":"[id^=\"buy-button-\"], .buy-button","watcherEligible":false,"productElementStyle":"-15px 0 35px 0"},{"name":"connatix-article","type":"connatix","selector":".l-segment:not(.l-feature) .c-entry-content","insertion":"after","maxSlots":1,"watcherEligible":false},{"name":"connatix-hub","type":"connatix","selector":".l-hub-page .c-pagination","insertion":"after","maxSlots":1,"watcherEligible":false},{"name":"connatix-article-desktop","type":"connatix","selector":".l-segment:not(.l-feature) .c-entry-content","insertion":"after","maxSlots":1,"watcherEligible":false,"filters":{"viewportWidth":{"min":728}}},{"name":"connatix-article-mobile","type":"connatix","selector":".l-segment:not(.l-feature) .c-entry-content","insertion":"after","maxSlots":1,"watcherEligible":false,"filters":{"viewportWidth":{"max":727}}},{"name":"connatix-feature","type":"connatix","selector":".l-feature .c-entry-content","insertion":"after","maxSlots":1,"watcherEligible":false},{"name":"connatix-feature-mobile","type":"connatix","selector":".l-feature .c-entry-content","insertion":"after","maxSlots":1,"watcherEligible":false,"filters":{"viewportWidth":{"max":727}}},{"name":"connatix-feature-desktop","type":"connatix","selector":".l-feature .c-entry-content","insertion":"after","maxSlots":1,"watcherEligible":false,"filters":{"viewportWidth":{"min":728}}},{"name":"editorially_placed_athena_mobile","slotClassName":"m-ad__editorially_placed_athena","prebidName":"mobile_article_body","selector":".m-ad.m-ad__editorial-athena-placement","sizes":[[1030,590],[620,366],[325,508],[325,204],[300,250],[300,"250v"]],"holdSize":[300,500],"filters":{"viewportWidth":{"max":727}}},{"name":"editorially_placed_athena_desktop","slotClassName":"m-ad__editorially_placed_athen ...
#   </script>
#   <link data-chorus-theme="chorus" href="https://www.eater.com/style/community/486/group/26594/5f73a183b402ece3a538469c09be2274/chorus.css" media="all" rel="stylesheet"/>
#   <meta content="https://www.eater.com/style/community/486/group/26594/9a40fdbbffb5ce6c7b099e32810d2eb9/tools.css" name="style-tools"/>
#   <script async="async" crossorigin="anonymous" integrity="sha256-qGA6iKChBI5BY+b6G1CbxxIN70Q326CvYBAqfEmS8EU= sha384-Ckdozq7jYlZ3mq9db4te8ve/tYFpyKcN7zfbjUZYLuWY/rrjChO8Aa9fezoEMAHx" src="https://cdn.vox-cdn.com/packs/js/concert_ads-f1797ae0ff80e696d213.js">
#   </script>
#   <script type="text/javascript">
#    function instantiateConcertAds() {
#     var concertAdsConfig = {
#       cmd: window.concertAdsQueue
#     };
#
#     for (var property in window.CONCERT_ADS_CONFIG) {
#       concertAdsConfig[property] = window.CONCERT_ADS_CONFIG[property];
#     }
#
#     window.concertAds = new ConcertAds(concertAdsConfig);
#   }
#   </script>
#   <script async="" onload="instantiateConcertAds()" src="https://cdn.concert.io/lib/concert-ads/v2-latest/concert_ads.js">
#   </script>
#   <script async="" src="https://c.amazon-adsystem.com/aax2/apstag.js">
#   </script>
#   <script async="" src="https://www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script async="" src="https://cdn.concert.io/lib/concert-concierge.2.8.0.min.js">
#   </script>
#   <script defer="" src="https://z.moatads.com/voxprebidheader841653991752/moatheader.js" type="text/javascript">
#   </script>
#   <meta content="Food news and dining guides for Minneapolis and St. Paul." name="description"/>
#   <link href="https://twincities.eater.com/" rel="canonical"/>
#   <meta content="Food news and dining guides for Minneapolis and St. Paul." property="og:description"/>
#   <meta content="549923288395304" property="fb:app_id"/>
#   <meta content="" property="og:image"/>
#   <meta content="Eater Twin Cities" property="og:site_name"/>
#   <meta content="Eater Twin Cities" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://twincities.eater.com/" property="og:url"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Eater Twin Cities" name="twitter:title"/>
#   <meta content="Food news and dining guides for Minneapolis and St. Paul." name="twitter:description"/>
#   <meta content="" name="twitter:image"/>
#   <meta content="EaterMPLS" name="twitter:site"/>
#   <link href="https://cdn.vox-cdn.com/uploads/chorus_asset/file/6253165/favicon.0.ico" rel="shortcut icon"/>
#   <link href="https://cdn.vox-cdn.com/uploads/chorus_asset/file/6253169/favicon-16x16.0.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="https://cdn.vox-cdn.com/uploads/chorus_asset/file/6253171/favicon-32x32.0.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://cdn.vox-cdn.com/uploads/chorus_asset/file/6253175/favicon-96x96.0.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="https://cdn.vox-cdn.com/uploads/chorus_asset/file/6253177/favicon-192x192.0.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="https://cdn.vox-cdn.com/uploads/chorus_asset/file/6253177/favicon-192x192.0.png" rel="apple-touch-icon" sizes="180x180"/>
#   <meta content="https://cdn.vox-cdn.com/uploads/chorus_asset/file/6253179/apple-touch-icon-144x144.0.png" name="msapplication-TileImage"/>
#   <meta content="#e20000" name="msapplication-TileColor"/>
#   <meta content="" name="theme-color"/>
#   <meta data-chorus-version="92522cfa7a7c6d879a7c1a1ee85df2c447cfdb94"/>
#   <link href="/rss/index.xml" rel="alternate" title="Eater Twin Cities" type="application/rss+xml"/>
#   <link href="https://twincities.eater.com/rss/front-page/index.xml" rel="alternate" title="Front Page" type="application/rss+xml"/>
#   <script async="true" src="https://ads.rubiconproject.com/prebid/7470_Vox_Eater_Prebid_DM.js" type="text/javascript">
#   </script>
#   <meta content="" http-equiv="origin-trial"/>
#   <meta content="" http-equiv="origin-trial"/>
#   <script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2021012601.js?21069944">
#   </script>
#   <script async="true" src="https://cdn.permutive.com/d2fb08da-1c03-4c8a-978f-ad8a96b4c31f-web.js" type="text/javascript">
#   </script>
#   <link as="script" href="https://adservice.google.com/adsid/integrator.js?domain=twincities.eater.com" rel="preload"/>
#   <script src="https://adservice.google.com/adsid/integrator.js?domain=twincities.eater.com" type="text/javascript">
#   </script>
#   <link href="https://03eae7766279862237afb4d9a97b797a.safeframe.googlesyndication.com/safeframe/1-0-37/html/container.html" rel="prefetch"/>
#   <link href="https://tpc.googlesyndication.com/safeframe/1-0-37/html/container.html" rel="prefetch"/>
#   <link href="//cds.connatix.com/p/95735/connatix.playspace.css" id="cnx-playspace-css" rel="stylesheet" type="text/css"/>
#   <meta content="upgrade-insecure-requests" http-equiv="Content-Security-Policy"/>
#   <link link="//vid.connatix.com/" rel="preconnect"/>
#   <link link="https://capi.connatix.com/" rel="preconnect"/>
#   <script async="" src="https://match.prod.bidr.io/cookie-sync/connatix?redir=https%3a%2f%2fcks.connatix.com%2fcks%3fpid%3d15%26ev%3d87f6ccf20ff2451eaebe52e8edabd778%26pname%3dBeeswax%26uid%3d{userid}" type="text/javascript">
#   </script>
#   <script async="" src="https://match.adsrvr.org/track/cmf/generic?ttd_pid=gapzaid&amp;ttd_tpi=1" type="text/javascript">
#   </script>
#   <script async="" src="https://ad.turn.com/r/cs?pid=67&amp;redir=https%3a%2f%2fcks.connatix.com%2fcks%3fpid%3d21%26ev%3d87f6ccf20ff2451eaebe52e8edabd778%26pname%3dAmobee%26uid%3D%23USER_ID%23" type="text/javascript">
#   </script>
#   <script async="" src="https://secure.adnxs.com/getuid?https%3a%2f%2fcks.connatix.com%2fcks%3fpid%3d6%26ev%3d87f6ccf20ff2451eaebe52e8edabd778%26pname%3dAppNexus%26uid%3d%24UID" type="text/javascript">
#   </script>
#   <script async="" src="https://sync.search.spotxchange.com/partner?adv_id=8600&amp;redir=https%3a%2f%2fcks.connatix.com%2fcks%3fpid%3d10%26ev%3d87f6ccf20ff2451eaebe52e8edabd778%26pname%3dSpotX%26uid%3d%24SPOTX_USER_ID" type="text/javascript">
#   </script>
#   <script>
#    (function() {
#             "use strict";
#             try {
#                 const playerApi = window.player_instance_b5361612024427251;
# var cnxVoxMacros = {
#   cust_params: "entry_type=" + CONCERT_ADS_CONFIG.dfpVariables.entry_type + "&entry_group=" + CONCERT_ADS_CONFIG.dfpVariables.entry_group + "&cts_keyword_list=" + concertAds.variables.cts_keyword_list + "&cts_keyword=" + concertAds.variables.cts_keyword + "&cts_iab_category=" + concertAds.variables.cts_iab_category + "&permutive=" + window.localStorage.getItem('_pdfps').replace('[', '').replace(']', '').replaceAll('"', '') + "&affiliation=" + CONCERT_ADS_CONFIG.dfpVariables.affiliation + "&team=" + concertAds.variables.team + "&cts_present=" + concertAds.variables.cts_present,
#   entry_type: CONCERT_ADS_CONFIG.dfpVariables.entry_type,
#   entry_group: CONCERT_ADS_CONFIG.dfpVariables.entry_group,
#   cts_list: concertAds.variables.cts_keyword_list,
#   cts_keyword: concertAds.variables.cts_keyword,
#   cts_iab_category: concertAds.variables.cts_iab_category,
#   permutive: window.localStorage.getItem('_pdfps').replace('[', '').replace(']', '').replaceAll('"', '').split(","),
#   affiliation: CONCERT_ADS_CONFIG.dfpVariables.affiliation,
#   entry_id: CONCERT_ADS_CONFIG.dfpVariables.entry_id,
#   team: concertAds.variables.team,
#   cts_present: concertAds.variables.cts_present
# };
#
# playerApi.setMacros(cnxVoxMacros);
# console.log(cnxVoxMacros)
# /*This sets custom macros for SpotX SSB and GAM line items*/
#
#             }catch(e){
#                 console.warn('---CnxCustomApiError---');
#                 console.warn(e.message);
#             }
#           })()
#   </script>
#   <script async="" charset="UTF-8" src="https://odb.outbrain.com/utils/get?url=https%3A%2F%2Ftwincities.eater.com%2F&amp;srcUrl=https%3A%2F%2Ftwincities.eater.com%2Frss%2Findex.xml&amp;idx=0&amp;rand=20322&amp;key=NANOWDGT01&amp;widgetJSId=AR_8&amp;va=true&amp;et=true&amp;format=html&amp;pdobuid=-1&amp;adblck=false&amp;abwl=false&amp;px=0&amp;py=6646&amp;vpd=6117&amp;settings=true&amp;recs=true&amp;version=2000193&amp;sig=z&amp;apv=false&amp;osLang=en-US&amp;winW=1036&amp;winH=529&amp;scrW=1280&amp;scrH=720&amp;dpr=1.5&amp;secured=true&amp;cmpStat=0&amp;ccpa=1YNY&amp;ccpaStat=1&amp;wdr-natlaz=true" type="text/javascript">
#   </script>
#   <script async="" data-for="hymnal" src="https://hymnal-prod.vox-cdn.com/libraries/underscore-1.5.1.min.js" type="text/javascript">
#   </script>
#   <script async="" data-for="hymnal" src="https://hymnal-prod.vox-cdn.com/libraries/jquery-1.10.2.min.gz.js" type="text/javascript">
#   </script>
#  </head>
#  <!--[if lte IE 9]><body class="ie9"><![endif]-->
#  <!--[if gte IE 10]><body class="ie"><![endif]-->
#  <body class="l-hub-page hub-front-page" data-group-id="26594" style="position: relative; z-index: -2000;">
#   <a class="sr-only link-skip" href="#content">
#    Skip to main content
#   </a>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-W8JKW6" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <svg height="0" style="position:absolute;display:none;" width="0">
#    <symbol id="icon-clock" viewbox="90 0 689 645" xmlns="http://www.w3.org/2000/svg">
#     <title>
#      clock
#     </title>
#     <path d="M489.1 322.5c0 15-5.4 27.9-16 38.6-10.7 10.7-23.6 16-38.6 16-23.7 0-40.3-10.9-49.9-32.8h-125c-6.4 0-11.6-2.1-15.7-6.1-4-4.1-6.1-9.3-6.1-15.7 0-6.4 2.1-11.6 6.1-15.7 4.1-4.1 9.4-6.1 15.8-6.1h125c5.9-13.2 15.3-22.5 28-28V125.8c0-6.4 2.1-11.6 6.1-15.7 4.1-4.1 9.3-6.1 15.7-6.1 6.4 0 11.6 2 15.7 6.1s6.1 9.3 6.1 15.7v146.8c21.9 9.5 32.9 26.1 32.8 49.9zm-54.6-306c84.2 0 156.3 29.9 216.2 89.8 59.9 59.9 89.8 131.9 89.8 216.2s-29.9 156.3-89.8 216.2c-59.9 59.9-131.9 89.8-216.2 89.8s-156.3-29.9-216.2-89.8c-59.9-59.9-89.8-131.9-89.8-216.2s29.9-156.3 89.8-216.2c59.9-59.9 132-89.8 216.2-89.8zm0 546.4c66.5 0 123.2-23.4 170.1-70.4 46.9-46.9 70.4-103.6 70.4-170.1s-23.4-123.2-70.4-170.1C557.7 105.5 501 82.1 434.5 82.1s-123.2 23.4-170.1 70.4C217.5 199.4 194 256.1 194 322.6s23.4 123.2 70.4 170.1c46.9 46.8 103.6 70.2 170.1 70.2z">
#     </path>
#    </symbol>
#    <symbol id="icon-close" viewbox="0 0 1000 1000" xmlns="http://www.w3.org/2000/svg">
#     <path d="M638.6 500l322.7-322.7c38.3-38.3 38.3-100.3 0-138.6S861 .4 822.7 38.7L500 361.4 177.3 38.7C139 .4 77 .4 38.7 38.7S.4 139 38.7 177.3L361.4 500 38.7 822.7C.4 861 .4 923 38.7 961.3 57.9 980.4 82.9 990 108 990s50.1-9.6 69.3-28.7L500 638.6l322.7 322.7c19.1 19.1 44.2 28.7 69.3 28.7 25.1 0 50.1-9.6 69.3-28.7 38.3-38.3 38.3-100.3 0-138.6L638.6 500z">
#     </path>
#    </symbol>
#    <symbol id="icon-close-map" viewbox="0 0 14 14" xmlns="http://www.w3.org/2000/svg">

#      </path>
#     </g>
#    </symbol>
#    <symbol id="icon-linkedin" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#     <path d="M.2 15.876h3.394V5.222H.2v10.654zM1.997 0C.8 0 0 .836 0 1.88s.8 1.88 1.997 1.88 1.997-.836 1.997-1.88C3.794.836 2.994 0 1.997 0zm9.985 4.804c-1.798 0-2.596 1.045-2.996 1.88V5.222H5.392c.2 1.045 0 10.862 0 10.862h3.395V9.818c0-.21 0-.627.2-.836.2-.626.798-1.253 1.796-1.253 1.2 0 1.798 1.04 1.798 2.5v5.64h3.4V9.82c0-3.342-1.79-5.014-3.99-5.014z">
#     </path>
#    </symbol>
#    <symbol id="icon-map-marker" viewbox="0 0 35.4 51" xmlns="http://www.w3.org/2000/svg">
#     <path d="M18 51.733c11.8-15.9 17.7-27.1 17.7-33.5 0-9.7-7.9-17.5-17.7-17.5S.3 8.533.3 18.233c0 6.4 5.9 17.6 17.7 33.5z">
#     </path>
#     <circle cx="18" cy="18" fill="#fff" r="8">
#     </circle>
#    </symbol>
#    <symbol id="icon-menu" viewbox="-375 489.5 37.2 30.3" xmlns="http://www.w3.org/2000/svg">
#     <title>
#      menu
#     </title>
#     <path d="M-367 489.5h29.1v3.8H-367zm-8 0h4.4v3.8h-4.4zm8 12.8h29.1v3.8H-367zm-8 0h4.4v3.8h-4.4zm8 13.7h29.1v3.8H-367zm-8 0h4.4v3.8h-4.4z">
#     </path>
#    </symbol>
#    <symbol id="icon-more" viewbox="0 0 179 96" xmlns="http://www.w3.org/2000/svg">
#     <title>
#      more-arrow
#     </title>
#     <path d="M178.86 47.677L129.776 0v34.313H0v26.625h116.296v.103h13.48v34.31l49.084-47.67">
#     </path>
#    </symbol>
#    <symbol id="icon-newsletter_signup" viewbox="0 0 50.062 37.479" xmlns="http://www.w3.org/2000/svg">
#     <path class="aushape-1" d="M25.085 21.866L.082 3.114A3.114 3.114 0 0 1 3.207-.012H46.96a3.113 3.113 0 0 1 3.126 3.126l-25 18.752zm0 5.613L50.087 8.726v25.64a3.113 3.113 0 0 1-3.125 3.125H3.208a3.113 3.113 0 0 1-3.125-3.125V8.727L25.085 27.48z">
#     </path>
#    </symbol>
#    <symbol id="icon-norgie-down" viewbox="0 0 832 512" xmlns="http://www.w3.org/2000/svg">
#     <path d="M15.244 98.497L379.433 495.43c20.249 22.24 53.137 22.23 73.373-.021.51-.608.71-1.47 1.25-2.077L817.152 98.259c20.233-22.224 20.223-58.326-.028-80.54-.202-.1-.531-.202-.735-.404C807.065 6.732 793.993-.005 779.353 0L52.923.208C38.073.212 24.903 7.286 15.43 18.18l-.2-.227c-20.314 22.325-20.304 58.33.023 80.543h-.008z">
#     </path>
#    </symbol>
#    <symbol id="icon-norgie-right" viewbox="0 0 512 832.328" xmlns="http://www.w3.org/2000/svg">
#     <path d="M98.278 817.088l397.038-364.076c22.245-20.243 22.245-53.13 0-73.373-.608-.51-1.47-.71-2.077-1.25L98.27 15.18c-22.218-20.24-58.32-20.24-80.54.005-.1.202-.202.53-.404.734C6.74 25.24 0 38.31 0 52.95v726.43c0 14.85 7.07 28.022 17.963 37.5l-.228.2c22.32 20.32 58.324 20.32 80.543 0z">
#     </path>
#    </symbol>
#    <symbol id="icon-opentable" viewbox="0 0 47.3 34.3" xmlns="http://www.w3.org/2000/svg">
#     <path d="M30.1 0C20.7 0 13 7.7 13 17.2s7.7 17.2 17.2 17.2 17.2-7.7 17.2-17.2C47.3 7.7 39.6 0 30.1 0zm0 21.5c-2.4 0-4.3-1.9-4.3-4.3s1.9-4.3 4.3-4.3 4.3 1.9 4.3 4.3c0 2.3-1.9 4.3-4.3 4.3zM0 17.2c0 2.4 1.9 4.3 4.3 4.3s4.3-1.9 4.3-4.3-1.9-4.3-4.3-4.3S0 14.8 0 17.2">
#     </path>
#    </symbol>
#    <symbol id="icon-pencil" viewbox="0 0 12 12" xmlns="http://www.w3.org/2000/svg">
#     <path d="M1.3 8.4c0 .1 0 .1 0 0L0 11.6c0 .1 0 .2.1.3 0 .1.1.1.1.1h.1l3.1-1.2s.1 0 .1-.1l6.2-6.2-2.2-2.3-6.2 6.2zm10.5-7L10.6.2c-.3-.3-.8-.3-1.1 0L8.2 1.5l2.2 2.2 1.3-1.3c.4-.2.4-.7.1-1z">
#     </path>
#    </symbol>
#    <symbol id="icon-pin" viewbox="0 0 60.7 93.3" xmlns="http://www.w3.org/2000/svg">
#     <path d="M57.2 34.6c0 4.8-1.3 9.3-3.5 13.2L31.8 87.5c-.3.5-.9.8-1.5.8-.7 0-1.2-.4-1.5-.8L6.9 47.7c-2.2-3.8-3.5-8.4-3.5-13.2 0-14.8 12-26.9 26.9-26.9 14.9.1 26.9 12.1 26.9 27zm-16.8 0c0-5.6-4.5-10.1-10.1-10.1S20.2 29 20.2 34.6s4.5 10.1 10.1 10.1 10.1-4.5 10.1-10.1z" xmlns="http://www.w3.org/2000/svg">
#     </path>
#    </symbol>
#    <symbol id="icon-pinterest" viewbox="-285 377 40 40" xmlns="http://www.w3.org/2000/svg">
#     <path d="M-265 377.1c-10.9 0-19.7 8.9-19.7 19.8 0 8.1 4.9 15 11.8 18.1-.1-1.4 0-3 .3-4.5.4-1.6 2.5-10.8 2.5-10.8s-.6-1.3-.6-3.1c0-2.9 1.7-5.1 3.8-5.1 1.8 0 2.7 1.3 2.7 3 0 1.8-1.2 4.5-1.7 7-.5 2.1 1 3.8 3.1 3.8 3.7 0 6.3-4.8 6.3-10.5 0-4.3-2.9-7.6-8.2-7.6-6 0-9.7 4.5-9.7 9.5 0 1.7.5 2.9 1.3 3.9.4.4.4.6.3 1.1l-.4 1.6c-.1.5-.5.7-1 .5-2.8-1.1-4-4.1-4-7.5 0-5.6 4.7-12.3 14.1-12.3 7.5 0 12.5 5.5 12.5 11.3 0 7.7-4.3 13.5-10.7 13.5-2.1 0-4.1-1.2-4.8-2.5 0 0-1.1 4.5-1.4 5.4-.4 1.5-1.2 3-2 4.2 1.8.5 3.7.8 5.6.8 10.9 0 19.7-8.8 19.7-19.7 0-11-8.9-19.9-19.8-19.9z">
#     </path>
#    </symbol>
#    <symbol id="icon-play" viewbox="-230 372 50 50" xmlns="http://www.w3.org/2000/svg">
#     <path d="M-214 376l25.6 21.1L-214 418v-42z" fill="#999">
#     </path>
#    </symbol>
#    <symbol id="icon-rec" viewbox="0 0 17 17" xmlns="http://www.w3.org/2000/svg">
#     <path d="M7.544.405l2.305 4.64 5.15.743L11.27 9.4l.88 5.1-4.61-2.407-4.6 2.407.88-5.1L.087 5.79l5.153-.744L7.545.404z">
#     </path>
#    </symbol>
#    <symbol id="icon-refresh" viewbox="0 0 450 386" xmlns="http://www.w3.org/2000/svg">
#     <path bx:origin="0.5 0.5" d="M352.629 288.14l96-111.9h-64.7c-2.3-27.9-10.5-54-23.5-77.3-27.4-49.2-75.8-85.1-133-95.6-.7-.1-1.5-.3-2.2-.4-.5-.1-.9-.2-1.4-.2-10.1-1.7-20.6-2.6-31.2-2.6h-.4c-90.9.2-167 63.6-186.7 148.6v.1c-.3 1.1-.5 2.2-.7 3.3-.1.5-.2.9-.3 1.4-.1.7-.3 1.4-.4 2.1-.2.9-.3 1.7-.5 2.6-.1.4-.1.7-.2 1.1l-.6 3.6v.2c-1 6.3-1.6 12.7-1.9 19.1v.8c-.1 1.4-.1 2.7-.2 4.1 0 1.6-.1 3.3-.1 5 0 1.7 0 3.3.1 5 0 1.4.1 2.7.2 4.1v.9c.3 6.5 1 12.9 1.9 19.1v.2l.6 3.6c.1.4.1.7.2 1.1.2.9.3 1.8.5 2.6.1.7.3 1.4.4 2.1.1.5.2 1 .3 1.4.2 1.1.5 2.2.7 3.2v.1c19.7 85 96.1 148.4 187.1 148.6 42.9-.1 83.1-14.2 116.9-40.7l7.5-5.9-43.2-46.2-6.2 4.6c-22.1 16.3-47.5 24.2-75 24.2-70.6 0-128-57-128-128s57.4-128 128-128c66.4 0 122.8 46.6 129.5 112h-73.5l104 112z" xmlns:bx="https://boxy-svg.com">
#     </path>
#    </symbol>
#    <symbol id="icon-right" viewbox="-27.7 455.1 337.2 791.1" xmlns="http://www.w3.org/2000/svg">
#     <path d="M6.9 455.1c9.5 0 19.8 4 27.7 14.3l262.9 350.1c7.9 9.5 11.9 22.2 11.9 31.7 0 11.9-4 22.2-11.9 31.7l-262.8 350c-11.9 14.3-31.7 17.4-47.5 7.9-15.8-9.5-17.4-31.7-7.9-45.9L239 850.3-20.8 508.2c-11.9-14.3-7.9-35.6 7.9-45.9 6.4-5.6 11.9-7.2 19.8-7.2" fill="inherit">
#     </path>
#    </symbol>
#    <symbol id="icon-rss" preserveaspectratio="xMinYMin meet" viewbox="0 0 1000 1000" xmlns="http://www.w3.org/2000/svg">
#     <path d="M0 866q0-55 39-94t94-39 94 39 39 94q0 56-39 94.5T133 999t-94-39-39-94zm0-335V340q179 0 331 88.5T571.5 669t88.5 331H468q0-194-137-331Q193 531 0 531zm0-339V0q203 0 388 79.5T707 293t213.5 319 79.5 388H808q0-164-64-314T571.5 428t-258-172T0 192z">
#     </path>
#    </symbol>
#    <symbol id="icon-search" viewbox="373.3 133.3 533.3 533.3" xmlns="http://www.w3.org/2000/svg">
-.98 0-1.62-.45-2.19-.86-.4-.28-.74-.52-1.14-.59-.21-.03-.42-.05-.62-.05-.36 0-.64.06-.85.1-.14.03-.26.05-.36.05-.25 0-.35-.15-.39-.28-.04-.13-.06-.26-.09-.38s-.07-.33-.11-.38C.89 12.9.2 12.62.04 12.23a.413.413 0 0 1-.036-.15.332.332 0 0 1 .28-.34c2.18-.36 3.16-2.59 3.2-2.684l.01-.02c.12-.23.15-.43.08-.58-.13-.29-.59-.44-.89-.54-.08-.02-.16-.05-.23-.08-.74-.29-.84-.62-.8-.85.06-.32.45-.53.78-.53.097 0 .18.02.256.05.28.13.527.2.737.2a.63.63 0 0 0 .31-.07l-.03-.38c-.065-1.086-.15-2.438.205-3.23C4.94.67 7.175.49 7.835.49l.28-.01h.04z">
#     </path>
#    </symbol>
#    <symbol id="icon-star" viewbox="0 0 17 17" xmlns="http://www.w3.org/2000/svg">
#     <path d="M7.544.405l2.305 4.64 5.15.743L11.27 9.4l.88 5.1-4.61-2.407-4.6 2.407.88-5.1L.087 5.79l5.153-.744L7.545.404z">
#     </path>
#    </symbol>
#    <symbol id="icon-thumb-down" viewbox="19.3 54.3 26.9 33.7" xmlns="http://www.w3.org/2000/svg">
#     <title>
#      no
#     </title>
#     <path d="M19.3 84.4c0-4.8 0-9.4.1-14 0-.4 1-1 1.6-1.2 4.2-1.1 7.7-3.2 9.6-7.3.7-1.6.9-3.4 1.5-5 .4-.9 1.2-1.7 1.8-2.5.7.8 2 1.6 2.1 2.5.2 2.2 0 4.5-.2 6.8-.1.9-.4 1.8-.6 3h5.1c1.2 0 2.4 0 3.5.2 1.9.3 2.4 1.3 2.2 3.2-.1 1.2.1 2.4.1 3.6 0 1 0 1.9-.1 2.9-.1 1.1 0 2.2-.3 3.1-1 2.6-2.1 5.2-3.4 7.6-.3.6-1.8.7-2.7.7-2.4.1-4.8.2-7.2 0-1.4-.1-2.9-.5-4-1.3-2.2-1.7-4.4-2.3-7.1-2.1-.6-.1-1.2-.2-2-.2z">
#     </path>
#    </symbol>
#    <symbol id="icon-thumb-up" viewbox="19.3 54.3 26.9 33.7" xmlns="http://www.w3.org/2000/svg">
#     <title>
#      yes
#     </title>
#     <path d="M19.3 84.4c0-4.8 0-9.4.1-14 0-.4 1-1 1.6-1.2 4.2-1.1 7.7-3.2 9.6-7.3.7-1.6.9-3.4 1.5-5 .4-.9 1.2-1.7 1.8-2.5.7.8 2 1.6 2.1 2.5.2 2.2 0 4.5-.2 6.8-.1.9-.4 1.8-.6 3h5.1c1.2 0 2.4 0 3.5.2 1.9.3 2.4 1.3 2.2 3.2-.1 1.2.1 2.4.1 3.6 0 1 0 1.9-.1 2.9-.1 1.1 0 2.2-.3 3.1-1 2.6-2.1 5.2-3.4 7.6-.3.6-1.8.7-2.7.7-2.4.1-4.8.2-7.2 0-1.4-.1-2.9-.5-4-1.3-2.2-1.7-4.4-2.3-7.1-2.1-.6-.1-1.2-.2-2-.2z">
#     </path>
#    </symbol>
#    <symbol id="icon-topics" viewbox="0 0 60.7 93.3" xmlns="http://www.w3.org/2000/svg">
#     <g xmlns="http://www.w3.org/2000/svg">
#      <path d="M2.5 21.5h55.2v11.8H2.5zM2.5 42.1h55.2v11.8H2.5zM2.5 64.3h55.2v11.8H2.5z">
#      </path>
#     </g>
#    </symbol>
#    <symbol id="icon-trending" viewbox="0 0 87 60" xmlns="http://www.w3.org/2000/svg">
#     <path d="M1.906 46.826c2.213 1.787 5.466 1.46 7.262-.743v-.006l5.26-6.45 8.378 11.286a5.171 5.171 0 0 0 4.827 2.035 5.128 5.128 0 0 0 4.124-3.215l7.96-20.208L51.26 56.577a5.155 5.155 0 0 0 4.754 3.13c.097 0 .19 0 .286-.007a5.172 5.172 0 0 0 4.66-3.667l10.98-36.787 4.854 9.902c1.234 2.552 4.33 3.613 6.89 2.37 2.56-1.234 3.636-4.314 2.386-6.86L75.42 2.888a5.15 5.15 0 0 0-5.067-2.87 5.135 5.135 0 0 0-4.52 3.653L55.146 39.42 44.28 13.93a5.142 5.142 0 0 0-4.827-3.127 5.157 5.157 0 0 0-4.73 3.263L25.56 37.343l-6.79-9.148a5.197 5.197 0 0 0-4.033-2.08 5.139 5.139 0 0 0-4.124 1.897L1.153 39.6a5.125 5.125 0 0 0 .753 7.226" fill-rule="evenodd">
#     </path>
#    </symbol>
#    <symbol id="icon-tumblr" viewbox="0 0 23.62 41.098" xmlns="http://www.w3.org/2000/svg">
#     <path d="M21.643 32.826c-.764.364-2.226.682-3.316.71-3.29.088-3.927-2.31-3.955-4.052V16.69h8.252v-6.22h-8.222V0h-6.02c-.1 0-.272.087-.296.307C7.734 3.512 6.234 9.135 0 11.382v5.31h4.16V30.12c0 4.595 3.39 11.126 12.343 10.974 3.02-.053 6.375-1.318 7.117-2.408l-1.977-5.86z">
#     </path>
#    </symbol>
#    <symbol id="icon-twitter" viewbox="0 0 44.71 36.327" xmlns="http://www.w3.org/2000/svg">
#     <path d="M44.71 4.295c-1.656.724-3.415 1.242-5.278 1.45A9.146 9.146 0 0 0 43.468.673a18.75 18.75 0 0 1-5.796 2.225C35.965 1.138 33.584 0 30.945 0a9.145 9.145 0 0 0-9.16 9.16c0 .724.052 1.448.208 2.12-7.607-.413-14.335-3.88-18.888-9.417-.777 1.345-1.242 2.742-1.242 4.45 0 3.157 1.604 5.95 4.088 7.607a9.376 9.376 0 0 1-4.14-1.138v.103c0 4.45 3.16 8.176 7.35 9.004-.77.2-1.6.31-2.43.31-.57 0-1.14-.06-1.71-.16 1.14 3.62 4.56 6.31 8.54 6.36-3.1 2.48-7.09 4.34-11.38 4.34-.72 0-1.45-.05-2.17-.16 4.04 2.59 8.9 3.72 14.08 3.72 16.87 0 26.08-13.97 26.08-26.08V9.05c1.76-1.294 3.32-2.9 4.56-4.76">
#     </path>
#    </symbol>
#    <symbol id="icon-up" viewbox="-235.8 423.2 35.7 21.3" xmlns="http://www.w3.org/2000/svg">
#     <path d="M-200.5 444.2L-218 424l-17.5 20.2" fill="none">
#     </path>
#    </symbol>
#    <symbol id="icon-user" viewbox="373.3 133.3 533.3 533.3" xmlns="http://www.w3.org/2000/svg">
#     <path d="M640 400c73.6 0 133.3-59.7 133.3-133.3S713.6 133.3 640 133.3 506.7 193 506.7 266.7 566.4 400 640 400zm0 66.7c-89 0-266.7 44.7-266.7 133.3v66.7h533.3V600c.1-88.7-177.6-133.3-266.6-133.3z">
#     </path>
#    </symbol>
#    <symbol id="icon-vimeo" viewbox="0 0 1146 1000" xmlns="http://www.w3.org/2000/svg">
#     <path d="M0 272q55-65 110-116t95.5-77.5 72.5-43T326 14l17-4q12-2 24-2 19 0 35 6 26 10 42.5 34.5t29 55 21.5 72 15 77.5 13.5 79.5T538 403q32 125 51.5 177.5T631 633q24 0 66.5-55.5T791 426q26-48 26-91 0-13-2-23-9-52-51-65-11-4-24-4-35 0-83 26 22-130 134-209Q876 0 965 0q12 0 24 1 102 8 139 90 18 38 18 88 0 29-6 61-18 102-69.5 208t-113 187.5-132.5 155-123.5 117T611 976q-42 24-78.5 24T463 979t-56-48-38-57q-18-38-97.5-298.5T175 295q-1-2-4-4t-13.5-4.5-24 0-36.5 14T47 333z">
#     </path>
# ...
#   <script src="https://mb.moatads.com/ot/v1?url=https%3A%2F%2Ftwincities.eater.com%2F&amp;pcode=moatot&amp;callback=OneTagNadoscallback_7345281" type="text/javascript">
#   </script>
#   <script src="https://mb.moatads.com/ii.js?lineItemId=5335564939&amp;callback=lineItemInfo5335564939Callback_74757778" type="text/javascript">
#   </script>
#   <iframe id="ob-user-test" src="https://widgets.outbrain.com/nanoWidget/externals/obUserFrame/test.html?lsd=8b3fbcbe-2688-4716-a856-0084fc96c5e1" style="display:none;width:0;height:0;">
#   </iframe>
#   <script id="hymnal__iframe-events-7f5203b12e1e12222beeb6d2d63e5917">
#    window.RegisterHymnalAd7f5203b12e1e12222beeb6d2d63e5917=// This file is inserted inline and then .toString() is called on it
# // and only if we need to listen to things outside of an iframe
# // do we eval and instantiate the code
#
# (function(window) {
#   "use strict";
#   var HymnalParent = {
#     ads: {},
#     listeningForMessages: false,
#     globalData: {},
#     queueRunning: false,
#     cancelWatch: false, // If this is true the setTimeout will stop
#     throttleInt: 100,
#     turboInt: 16,
#     // By toggling booleans we can assure that our event handlers
#     // don't block the main render thread in the browser
#     // thus making our ad viewers a little bit happier
#     ev: {
#       scroll: false,
#       resize: false,
#       unisonTabBarVisibility: false
#     },
#     // Constructor function to build a new ad object, called by Init
#     childAd: function(opts) {
#      return {
#       secureToken: opts.token,
#       messageTarget: null,
#       isConnected: false,
#       iframed: opts.inIframe,
#       containerEl: null,
#       data: {},
#       turboOn: false,
#       origin: null
#      };
#     },
#
#     // This function is the only function exposed publicly
#     // Opts is an object that contains a token (adId-randomNumber) and
#     // a inIframe boolean.
#     // Calling this will register an ad to receive messages as this lib dispatches them
#     init: function(opts) {
#       // we'll use the token as the key
#       // since every message from the child will include the token
#       this.ads[opts.token] = this.childAd(opts);
#
#       if (!this.listeningForMessages) {
#         window.addEventListener('message', this.messageHandler.bind(this));
#         this.listeningForMessages = true;
#       }
#
#       // if there's no iframe the parent can initiate the messages
#       // otherwise we wait for a message from the frame to get the target
#       if (!opts.inIframe) {
#         // this Timeout is to help avoid a race condition where we query the dom before
#         // the iframe busting js is finished.
#         setTimeout(function(){
#           var id = opts.token.split('_')[0];
#           this.ads[opts.token].containerEl = document.querySelector('[data-hymnal-id="' + id + '"]');
#           if (this.ads[opts.token].containerEl) {
#             this.ads[opts.token].messageTarget = this.windowLocation();
#             this.ads[opts.token].isConnected = true;
#             this.defaultParams(opts.token);
#           } else {
#             this.ads[opts.token].containerEl = false;
#           }
#         }.bind(this), 0);
#       }
#
#       if (!this.queueRunning) {
#         this.createQueue();
#       } else {
#         this.containerElement = false;
#       }
#     },
#
#     adDimensions: function() {
#
#       var elementToMeasure;
#
#       if (this.containerElement) {
#         elementToMeasure = document.querySelectorAll(this.containerElement)[0];
#       } else {
#         elementToMeasure = this.frameTarget.frameElement
#       }
#
#       // Lets make sure we can really call this here
#       if(elementToMeasure && typeof elementToMeasure.getBoundingClientRect === 'function'){
#         return elementToMeasure.getBoundingClientRect();
#       } else {
#         return { height: 0, width: 0, top:0 };
#       }
#     },
#
#     checkForChange: function() {
#       if (!this.visObserver) {
#         this.visObserver = this.observePageVisibility();
#       }
#
#       this.watcher = false;
#       var handler = '';
#       for (var evType in this.ev) {
#         if (this.ev.hasOwnProperty(evType) && this.ev[evType]) {
#           // Handler functions are 'onscroll', 'onresize', on 'unisonTabBarVisibility'
#           handler = 'on' + evType;
#           // this.ev[evType] is either a boolean or the detail attribute from a custom event
#           this[handler]( this.ev[evType] );
#         }
#       }
#
#       if (this.cancelWatch) {
#         clearTimeout(this.watcher);
#         this.watcher = undefined;
#       } else {
#         this.throttledWatcher(this.checkForChange, this.throttleInt);
#       }
#     },
#
#     createQueue: function() {
#       for (var evnt in this.ev) {
#         if (this.ev.hasOwnProperty(evnt)) {
#           window.addEventListener(evnt, this.eventHandler.bind(this));
#         }
#       }
#       this.throttledWatcher(this.checkForChange, this.throttleInt);
#       this.queueRunning = true;
#     },
#
#     currentData: function(key) {
#       var data = this.ads[key].data;
#       for (var key in this.globalData) {
#         if (this.globalData.hasOwnProperty(key)) {
#           data[key] = this.globalData[key];
#         }
#       }
#       return data;
#     },
#
#     defaultParams: function(key) {
#       var d = this.ads[key].data;
#       var g = this.globalData;
#       // Global properties are setup once and then updated on scroll/resize
#       if (!g.windowWidth) {
#         g.windowWidth = this.getWindowWidth();
#       }
#       if (!g.windowHeight) {
#         g.windowHeight = this.getWindowHeight();
#       }
#       if (!g.documentHeight) {
#         g.documentHeight = document.body.clientHeight;
#       }
#       if (!g.scrollOffset) {
#         g.scrollOffset = window.scrollY || window.pageYOffset;
#       }
#
#       if (!g.scrollDirection) {
#         g.scrollDirection = "down";
#       }
#       // does not need to be changed after this call
#       if (!g.isUnison) {
#         var unison = false;
#         if (window.ChorusAds && window.ChorusAds.is_unison) {
#           unison = true;
#         }
#         g.isUnison = unison;
#       }
#
#       if (!g.unisonTabBarVisibility) {
#         g.unisonTabBarVisibility = false;
#       }
#
#       var frameDims = this.getFrameDimensions(key);
#       d.frameHeight = frameDims.height;
#       d.frameWidth = frameDims.width;
#       d.frameTopPos = frameDims.top;
#       d.framePosOnPage = this.getframePosOnPage(frameDims.top);
#       d.scrollPercent = this.getScrollPercentage(key);
#
#       this.dispatchChange(key, "initial");
#       return d;
#     },
#
#     dispatchChange: function(key, evType) {
#       var data;
#       if (evType && evType === "turbo") {
#         data = this.getScrollPercentage(key);
#       } else {
#         data = this.currentData(key);
#       }
#
#       var params = {
#         type: evType || '',
#         params: data,
#         token: this.ads[key].secureToken,
#         sender: "parent"
#       };
#       if (this.ads[key].iframed && this.ads[key].messageTarget && this.ads[key].messageTarget.postMessage) {
#         this.ads[key].messageTarget.postMessage(params, this.ads[key].origin);
#       } else {
#         window.postMessage(params, this.windowLocation());
#       }
#     },
#
#     turboMode: function(key) {
#       var d = this.currentData(key);
#       var e = this.ev;
#       this.ads[key].turboOn = true;
#       if (e.scroll || e.resize) {
#         d.scrollPercent = this.getScrollPercentage(key);
#
#         this.dispatchChange(key, "turbo");
#       }
#       this.throttledWatcher(this.turboMode, this.turboInt, key);
#     },
#
#     eventHandler: function(ev) {
#       // scroll and resize events have no detail key
#       this.ev[ev.type] = ev.detail ? ev.detail : true;
#     },
#
#     getFrameDimensions: function(key) {
#       if (this.ads[key].containerEl) {
#         return this.ads[key].containerEl.getBoundingClientRect();
#       } else {
#         // IF the container el doesn't exist
#         return  {height: 0, width: 0, top: 0}
#       }
#     },
#
#     getframePosOnPage: function(top) {
#       return Math.abs(document.body.getBoundingClientRect().top - top);
#     },
#
#     getAdMidpoint: function(key) {
#       var frame = this.getFrameDimensions(key);
#       var y = window.scrollY || window.pageYOffset;
#       return frame.top + (frame.height / 2) + y;
#     },
#
#     getScrollRange: function(key) {
#       var frame = this.currentData(key);
#       var lower = Math.floor(frame.framePosOnPage - window.innerHeight);
#       var upper = Math.ceil(frame.framePosOnPage + frame.frameHeight);
#       return [lower, upper];
#     },
#
#     // formula from the magnificent stackexchange
#     //http://math.stackexchange.com/questions/51509/how-to-calculate-percentage-of-value-inside-arbitrary-range
#     getScrollPercentage: function(key) {
#       var bounds = this.getScrollRange(key);
#       var y = window.scrollY || window.pageYOffset;
#
#       var pct = (y - bounds[0]) / (bounds[1] - bounds[0]);
#       return pct;
#     },
#
#     getWindowWidth: function() {
#       var w = window.top.innerWidth || document.documentElement.clientWidth;
#       // this may be true on mobile devices with high DPI screens
#       if (w > screen.width) {
#         w = screen.width;
#       }
#       return w;
#     },
#
#     getWindowHeight: function() {
#       var h = window.top.innerHeight || document.documentElement.clientHeight;
#
#       if (h > screen.height) {
#         h = screen.height;
#       }
#       return h;
#     },
#
#     observePageVisibility: function() {
#       if (this.visObserver) {
#         return true;
#       }
#
#       var prefixes = ['h', 'mozH', 'msH', 'webkitH'];
#       var hidden, visibilityChange
#       prefixes.forEach(function(prefix) {
#         if (typeof document[prefix + 'idden'] !== undefined) {
#           hidden = prefix + 'idden';
#           if (prefix === 'h') {
#             visibilityChange = 'visibilitychange';
#           } else {
#             visibilityChange = prefix.slice(0, -1) + 'visibilitychange';
#           }
#         }
#       });
#       if (typeof document[hidden] === 'undefined') {
#         return false;
#       }
#
#       document.addEventListener(visibilityChange, function() {
#         this.visObserver = true;
#         if (document[hidden]) {
#           this.cancelWatch = true;
#         } else {
#           this.cancelWatch = false;
#           this.checkForChange();
#         }
#       }.bind(this))
#       return true;
#     },
#
#     throttledWatcher: function(cb, int, key) {
#       setTimeout(cb.bind(this), int, key);
#     },
#
#     messageHandler: function(ev) {
#       var isChild = ev.data.sender && ev.data.sender === "child";
#       var ad = ev.data.token && this.ads[ev.data.token];
#       if (!isChild || !ad) {
#         return false;
#       }
#       ad.messageTarget = ev.source;
#       ad.containerEl = ev.source.frameElement;
#
#       if (ev.data.inIframe) {
#         ad.iframed = true;
#       }
#
#       // This will already exist if the ad is not in an iframe
#       if (!ad.origin) {
#         ad.origin = ev.origin;
#       }
#
#       // If the ad is in an iframe but we don't have a container element
#       // that probably means we're sandboxed, most likely on a partner network
#       // let's pretend that we're not in a iframe in that case.
#       if (ad.iframed && !ad.containerEl) {
#         ad.containerEl = document.querySelector('[data-hymnal-id]');
#         ad.iframed = false;
#         ad.origin = this.windowLocation();
#       }
#
#       if (ev.data.func && ev.data.func in this) {
#         this[ev.data.func](ev.data.token);
#       }
#
#       if (ev.data.interval) {
#         this.throttleInt = ev.data.interval;
#       }
#
#       if (!ad.isConnected) {
#         this.defaultParams(ad.secureToken);
#         ad.isConnected = true;
#       }
#
#       if (!this.queueRunning) {
#         this.createQueue();
#       } else {
#         return this.dispatchChange(ad.secureToken, "receipt");
#       }
#     },
#
#     // loops through all registered ads and updates all requested attributes
#     // then dispatches change messages for every ad
#     // ev is required, attrs is optional
#     updateRegisteredAds: function(ev, attrs) {
#       var frameDims;
#       for (var key in this.ads) {
#         if (!this.ads.hasOwnProperty(key) ){
#           continue;
#         }
#
#         // we don't need to touch the dom if this is just an event dispatch
#         if (attrs.length > 0) {
#           frameDims = this.getFrameDimensions(key);
#         }
#
#         if (attrs.indexOf('frameHeight') > -1 &&
#           frameDims.height !== this.ads[key].data.frameHeight) {
#           this.ads[key].data.frameHeight = frameDims.height;
#         }
#
#         if (attrs.indexOf('frameWidth') > -1 &&
#           frameDims.width !== this.ads[key].data.frameWidth) {
#           this.ads[key].data.frameWidth = frameDims.width;
#         }
#
#         if (attrs.indexOf('frameTopPos') > -1) {
#           this.ads[key].data.frameTopPos = frameDims.top;
#         }
#
#         if (attrs.indexOf('framePosOnPage') > -1) {
#           this.ads[key].data.framePosOnPage = this.getframePosOnPage(frameDims.top);
#         }
#
#         if (attrs.indexOf('scrollPercent') > -1) {
#           this.ads[key].data.scrollPercent = this.getScrollPercentage(key);
#         }
#
#         this.dispatchChange(key, ev);
#       }
#     },
#
#     onscroll: function() {
#       this.ev.scroll = false;
#       var g = this.globalData;
#       g.documentHeight = document.body.clientHeight;
#       var currentScroll = window.scrollY || window.pageYOffset;
#       g.scrollDirection = currentScroll > g.scrollOffset  ? "down" : "up";
#       g.scrollOffset = currentScroll;
#
#       this.updateRegisteredAds('scroll', ['frameHeight', 'frameWidth', 'frameTopPos', 'framePosOnPage', 'scrollPercent']);
#     },
#
#     onresize: function() {
#       this.ev.resize = false;
#       var g = this.globalData;
#       g.windowWidth = this.getWindowWidth();
#       g.windowHeight = this.getWindowHeight();
#       g.documentHeight = document.body.clientHeight;
#
#       this.updateRegisteredAds('resize', ['frameHeight', 'frameWidth', 'frameTopPos', 'framePosOnPage', 'scrollPercent']);
#     },
#
#     /*
#     * This function gives an ad the option to update its refresh ability inside its slot.
#     * The dispatched custom Event will be used in the ChorusAds object found here:
#     * sbn/app_unison/frontend/components/apps/chorus_ads/lib/slot.js
#     */
#
#     refreshEligibilityEvent: function(key, detail) {
#       this.ads[key].containerEl.dispatchEvent(new CustomEvent('refreshEligibilityToggle', {
#         bubbles:true,
#         detail: detail
#       }));
#     },
#
#     enableRefreshEligibility: function(key) {
#       this.refreshEligibilityEvent(key, {refresh: true});
#     },
#
#     disableRefreshEligibility: function(key) {
#       this.refreshEligibilityEvent(key, {refresh: false});
#     },
#
#     // unison tab bar API
#
#     onunisonTabBarVisibility: function(detail) {
#       // reset the event checker
#       this.ev.unisonTabBarVisibility = false;
#       this.globalData.unisonTabBarVisibility = detail.visible;
#       this.updateRegisteredAds('unisonTabBarVisibility', []);
#     },
#
#     unisonTabBarEvent: function(detail) {
#       document.dispatchEvent(new CustomEvent('unisonTabBarOverride', {detail: detail}));
#     },
#
#     showUnisonTabBar: function() {
#       this.unisonTabBarEvent({visibility: true});
#     },
#
#     hideUnisonTabBar: function() {
#       this.unisonTabBarEvent({visibility: false});
#     },
#
#     resetToDefaultUnisonTabBar: function() {
#       this.unisonTabBarEvent({reset: true});
#     },
#
#     windowLocation: function() {
#       var l = window.location;
#       if (!l.origin){
#         window.location.origin = l.protocol + "//" + l.hostname + (l.port ? ':' + l.port: '');
#       }
#       return window.location.origin;
#     }
#
#   };
#   return HymnalParent.init.bind(HymnalParent);
# })(window);
#  window.RegisterHymnalAd7f5203b12e1e12222beeb6d2d63e5917({inIframe: false, token: "b302176a-5550-482a-8d62-e9be0489394e_770"});
#   </script>
#   <script src="https://analytics.twitter.com/i/adsct?type=javascript&amp;version=1.1.0&amp;p_id=Twitter&amp;p_user_id=0&amp;txn_id=nzjqi&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Ftwincities.eater.com%2F" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
blurb = soup.select_one("div", class_="c-compact-river")
title = blurb.find("h2", class_="c-entry-box--compact__title")
# .get_text()
print(title)
# Out:
# None

# %%
news_p = blurb.find("div", class_='rollover_description_inner').get_text()
print(news_p)
# Out:
# During this next phase, the program will mature critical technologies and make critical design decisions as well as assess industry partnerships.

# %%
### JPL Mars Space Images - Featured Image
# time.sleep(2)
# url2 = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
# browser.visit(url2)

# %%
# browser.click_link_by_id('full_image')
# browser.click_link_by_partial_href('/spaceimages/details')

# html = browser.html
# soup = bs(html, 'html.parser')

# lede = soup.find('figure', class_='lede')
# link = lede.find('a')
# href = link['href']

# print(href)
# Out:
# C:\Users\kylie\anaconda3\envs\PythonData\lib\site-packages\splinter\driver\webdriver\__init__.py:485: FutureWarning: browser.find_link_by_partial_href is deprecated. Use browser.links.find_by_partial_href instead.
#   FutureWarning,
# /spaceimages/images/largesize/PIA07137_hires.jpg

# %%
# features_image_url = 'https://www.jpl.nasa.gov' + href
# print(features_image_url)
# Out:
# https://www.jpl.nasa.gov/spaceimages/images/largesize/PIA07137_hires.jpg

# %%
### Mars Facts
# time.sleep(2)
# url3 = 'https://space-facts.com/mars/'
# browser.visit(url3)

# %%
# tables = pd.read_html(url3)

# %%
# type(tables)
# df = tables[0]
# df.columns = ['Mars Facts', '']
# df
# Out:
#              Mars Facts
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
# df.set_index('Mars Facts', inplace=True)
# df
# Out:
#
# Mars Facts
# Equatorial Diameter:                       6,792 km
# Polar Diameter:                            6,752 km
# Mass:                 6.39 × 10^23 kg (0.11 Earths)
# Moons:                          2 (Phobos & Deimos)
# Orbit Distance:            227,943,824 km (1.38 AU)
# Orbit Period:                  687 days (1.9 years)
# Surface Temperature:                   -87 to -5 °C
# First Record:                     2nd millennium BC
# Recorded By:                   Egyptian astronomers

# %%
# html_table = df.to_html()
# html_table = html_table.replace('\n', '')
# html_table
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th></th>    </tr>    <tr>      <th>Mars Facts</th>      <th></th>    </tr>  </thead>  <tbody>    <tr>      <th>Equatorial Diameter:</th>      <td>6,792 km</td>    </tr>    <tr>      <th>Polar Diameter:</th>      <td>6,752 km</td>    </tr>    <tr>      <th>Mass:</th>      <td>6.39 × 10^23 kg (0.11 Earths)</td>    </tr>    <tr>      <th>Moons:</th>      <td>2 (Phobos &amp; Deimos)</td>    </tr>    <tr>      <th>Orbit Distance:</th>      <td>227,943,824 km (1.38 AU)</td>    </tr>    <tr>      <th>Orbit Period:</th>      <td>687 days (1.9 years)</td>    </tr>    <tr>      <th>Surface Temperature:</th>      <td>-87 to -5 °C</td>    </tr>    <tr>      <th>First Record:</th>      <td>2nd millennium BC</td>    </tr>    <tr>      <th>Recorded By:</th>      <td>Egyptian astronomers</td>    </tr>  </tbody></table>'

# %%
### Mars Hemispheres
# time.sleep(2)
# url4 = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
# browser.visit(url4)

# %%
# <img class="wide-image" src="/cache/images/f5e372a36edfa389625da6d0cc25d905_cerberus_enhanced.tif_full.jpg">

# html = browser.html
# soup = bs(html, 'html.parser')

# dict_list = []

# items = soup.find_all('div', class_='item')

# for item in items:
#     h3 = item.find('h3').get_text()
#     h3 = h3.replace(' Enhanced','')
#     dict = {"title": h3}

#     browser.find_by_tag('h3').click()
#     browser.find_by_id('wide-image')

#     html = browser.html
#     soup = bs(html, 'html.parser')

#     downloads = soup.find('div', class_='downloads')
#     li = downloads.find('li')
#     link1 = li.find('a')
#     href1 = link1['href']
    
#     dict.update({"img_url": href1})
#     dict_list.append(dict)
    
#     browser.visit(url4)
    
    
# print(dict_list)
# browser.quit()
# Out:
# [{'title': 'Cerberus Hemisphere', 'img_url': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg'}, {'title': 'Schiaparelli Hemisphere', 'img_url': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg'}, {'title': 'Syrtis Major Hemisphere', 'img_url': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg'}, {'title': 'Valles Marineris Hemisphere', 'img_url': 'https://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg'}]
